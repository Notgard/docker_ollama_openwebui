# %%
print("hello from jupyter notebook")
# Out:
# hello from jupyter notebook

# %%
# %%bash
# ls -alkh
# nvcc --version
# nvidia-smi
# gcc --version
# g++ --version
# pip --version
# python --version
# pip list
# df -kh
# Out:
# total 28K
# drwxrwxr-x 3 jovyan jovyan 4.0K Oct  9 11:46 .
# drwxrwxr-x 5 jovyan jovyan 4.0K Oct  9 11:43 ..
# drwxrwxr-x 2 jovyan jovyan 4.0K Oct  9 11:45 .ipynb_checkpoints
# -rw-rw-r-- 1 jovyan jovyan  130 Oct  8 15:17 test.c
# -rw-r--r-- 1 jovyan users  8.3K Oct  9 11:46 test.ipynb
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Wed Oct  9 11:47:28 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.107.02             Driver Version: 550.107.02     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# ...
